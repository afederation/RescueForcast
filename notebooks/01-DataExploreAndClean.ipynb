# %% [markdown]
# # Data Gathering, Exploration and Cleaning
#
# Before building the model, I want to understand the nature of the data we have. There are several data sources we're using, all index by date.
#
# **Outcome Data**
# - SAR response. This data set indicates whether or not there was a SAR call on a specified day.
#
# **Features**
# - Date features
# - Weather from [NOAA](https://www.ncdc.noaa.gov/cdo-web/)

# %% [markdown]
# ## SAR Response Data
#
# First, let's dig into the SAR response data. I've deleted the mission names for privacy reasons. How often does a mission happen?
# - **DEM** is an id number provided by the state
# - **Responders** is the number of responders
# - **Hours** is the sum of the number of hours provided by all responders
# - **Miles** is the sum of the number of hours provided by all responders
#
# These other fields may me interesting for downstream analyses, but probably aren't important for this first classification problemn approach

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import matplotlib.style as style

# %matplotlib inline
style.use('seaborn-notebook')

# %%
input_filepath = '../data/raw/'
sar_header = ['DEM', 'date', 'responders', 'hours', 'miles']
sar_data = pd.read_csv(f'{input_filepath}KCSARA.csv', header=None, 
                       parse_dates=['date'], names=sar_header)
sar_data = pd.DataFrame(sar_data)
sar_data.head()
# Out:
#        DEM       date  responders  hours  miles
# 0  06-1499 1800-01-01           0    NaN    NaN
# 1   313531 1800-01-01           7   19.5  290.0
# 2   07-688 1800-01-01           0    NaN    NaN
# 3      NaN 2064-02-16           0    NaN    NaN
# 4      NaN 2064-08-08           0    NaN    NaN

# %%
sar_data.shape
# Out:
# (2703, 5)

# %%
sar_data.tail()
# Out:
#             DEM       date  responders   hours   miles
# 2698    19-1272 2019-04-20          51   20.68  1546.0
# 2699  19-ES-026 2019-04-20          49  671.75  8735.0
# 2700    19-1290 2019-04-21          43  289.25  2091.0
# 2701    19-1282 2019-04-21          29  101.25  1307.0
# 2702    19-1278 2019-04-21          43  116.37  2654.0

# %% [markdown]
# There are NAs in the date column, we need to get rid of those

# %%
sar_data = sar_data[pd.notnull(sar_data.date)]

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(sar_data.describe(include='all').T)
# Out:
#            count unique                  top freq                first  \
# DEM         2640   2522              15-4980    9                  NaN
# date        2703   2198  2017-06-25 00:00:00    5  1800-01-01 00:00:00
# responders  2703    NaN                  NaN  NaN                  NaN
# hours       2337    NaN                  NaN  NaN                  NaN
# miles       2274    NaN                  NaN  NaN                  NaN
#
#                            last     mean      std   min     25%    50%   75%  \
# DEM                         NaN      NaN      NaN   NaN     NaN    NaN   NaN
# date        2066-09-04 00:00:00      NaN      NaN   NaN     NaN    NaN   NaN
# responders                  NaN  16.8957  17.0741     0       4     12    26
# hours                       NaN  118.676  193.433  0.08    19.5  63.25   143
# miles                       NaN  1097.09  1383.53     0  251.75  778.5  1460
#
#                 max
# DEM             NaN
# date            NaN
# ...

# %% [markdown]
# ## Does the data make sense?
#
# 1. How many calls occur per year?
#
# We'll take the add_datepart function from fast.ai, add some functionality and use it to add some date features

# %%
#Use a function from fast.ai to extract interesting data info

def add_datepart(df, fldname, drop=True, time=False, errors="raise"):
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True, errors=errors)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

add_datepart(sar_data, 'date', drop=False)
sar_data.head()
# Out:
#        DEM       date  responders  hours  miles  Year  Month  Week  Day  \
# 0  06-1499 1800-01-01           0    NaN    NaN  1800      1     1    1
# 1   313531 1800-01-01           7   19.5  290.0  1800      1     1    1
# 2   07-688 1800-01-01           0    NaN    NaN  1800      1     1    1
# 3      NaN 2064-02-16           0    NaN    NaN  2064      2     7   16
# 4      NaN 2064-08-08           0    NaN    NaN  2064      8    32    8
#
#    Dayofweek  Dayofyear  Is_month_end  Is_month_start  Is_quarter_end  \
# 0          2          1         False            True           False
# 1          2          1         False            True           False
# 2          2          1         False            True           False
# 3          5         47         False           False           False
# 4          4        221         False           False           False
#
#    Is_quarter_start  Is_year_end  Is_year_start     Elapsed
# ...

# %%
def missions_per_year(df):
    '''
    From a dataframe with the 'Year' column,
    Plot a graph showing the number of missions per year
    '''
    
    missions_per_year = df.Year.value_counts()
    plt.plot(missions_per_year.sort_index())
    plt.show()


missions_per_year(sar_data)

# %% [markdown]
# Clearly some weirdness happening here, lets cut the data to remove anything from before 1980 and in the future.

# %%
sar_data = sar_data[(sar_data.Year < 2020) & (sar_data.Year > 1979)]
missions_per_year(sar_data)

# %% [markdown]
# It seems to me that the data prior to 2001 is incomplete in some instances and likely follows a different model than the years proir to 2001. Let's focus this analysis on the missions after the spike. For example, in 1991 there are only missions in months 1-4, even though we know the most popular months are the summer months. This is seen in several other years as well.

# %%
sar_data = sar_data[(sar_data.Year < 2020) & (sar_data.Year > 2001)]
missions_per_year(sar_data)

# %% [markdown]
# ### Missions per week
#
# As shown below, the summer weeks and weekends get the highest mission density, Saturday in particular.

# %%
def missions_per_week(df):
    '''
    From a dataframe with the 'Week' column,
    Plot a graph showing the number of missions per week
    '''
    
    missions_per_week = df.Week.value_counts()
    plt.plot(missions_per_week.sort_index())
    plt.xlabel('Week of Year')
    plt.ylabel('# of Calls')
    plt.title('Total SAR Calls per Week')
    plt.show()
    
missions_per_week(sar_data)

# %%
missions_per_weekday = sar_data.Dayofweek.value_counts()
plt.plot(missions_per_weekday.sort_index())
plt.xlabel('Day of Week')
plt.ylabel('# of Calls')
plt.title('Total SAR Calls per Day')
plt.savefig('../reports/figures/callsperday.png')
plt.show()

# %% [markdown]
# ### Clean data to include all dates and a mission class
#
# Before we can do any ML, we need a table with all dates that indicates whether a mission happened or not. The rest of the variables in this table aren't important for our predictions.

# %%
date_range = pd.date_range(start='1/1/2002', end='1/1/2019')

clean_table = []

for d in date_range:
    if sar_data.date.isin([d]).any():
        clean_table.append([d,1])
    else:
        clean_table.append([d,0])
               
sar_clean = pd.DataFrame(clean_table)
sar_clean.columns = ['date','mission']
sar_clean.head()
# Out:
#         date  mission
# 0 2002-01-01        1
# 1 2002-01-02        0
# 2 2002-01-03        1
# 3 2002-01-04        0
# 4 2002-01-05        1

# %%
# Add the date parts to this new tidy table
add_datepart(sar_clean, 'date', drop=False)
sar_clean.head()
# Out:
#         date  mission  Year  Month  Week  Day  Dayofweek  Dayofyear  \
# 0 2002-01-01        1  2002      1     1    1          1          1
# 1 2002-01-02        0  2002      1     1    2          2          2
# 2 2002-01-03        1  2002      1     1    3          3          3
# 3 2002-01-04        0  2002      1     1    4          4          4
# 4 2002-01-05        1  2002      1     1    5          5          5
#
#    Is_month_end  Is_month_start  Is_quarter_end  Is_quarter_start  \
# 0         False            True           False              True
# 1         False           False           False             False
# 2         False           False           False             False
# 3         False           False           False             False
# 4         False           False           False             False
#
#    Is_year_end  Is_year_start     Elapsed
# 0        False           True  1009843200
# 1        False          False  1009929600
# ...

# %%
sar_clean.mission.mean()
# Out:
# 0.29015873015873017

# %% [markdown]
# How often is there a call? 29% of ther time.

# %% [markdown]
# ## Weather Data
#
# We're pulling data from two weather stations in Washington State. Boeing field is a little south of Seattle and will represent the 'city' weather, and Mount Gardner is a weather station in the Cascade Mountain Range East of Seattle and will report on the 'mountain' weather in the model.
#
# I couldn't find freely accessible weather forecast data, which would be more relevent for predicting future missions. To try and deal with this, I'll only use weather features that we can expect a weather forecast to contain.
#
# I'm not sure what to expect, poor weather will mean less people in the mountains, but it could also mean more dangerous conditions for the people that are out.

# %%
boeing = pd.read_csv(f'{input_filepath}boeing.csv', parse_dates=[2])
boeing.describe()
# Out:
#               AWND         FMTM         PGTM         PRCP         TAVG  \
# count  6299.000000  1461.000000  6156.000000  6302.000000  1307.000000
# mean      5.265264  1389.337440  1354.393762     0.101831    54.160673
# std       2.630277   549.960908   516.171642     0.235165    10.433713
# min       0.000000     7.000000     0.000000     0.000000     0.000000
# 25%       3.360000  1136.000000  1125.000000     0.000000    46.000000
# 50%       4.700000  1450.000000  1429.000000     0.000000    53.000000
# 75%       6.710000  1724.000000  1658.000000     0.090000    62.000000
# max      18.790000  2359.000000  2359.000000     4.040000    82.000000
#
#               TMAX         TMIN   TSUN         WDF2         WDF5         WSF2  \
# count  6286.000000  6286.000000  928.0  6309.000000  6309.000000  6309.000000
# mean     61.200127    46.325167    0.0   213.889681   222.258678    13.580472
# std      12.532549     9.799496    0.0    76.979837    72.996940     4.551554
# ...

# %%
gardner = pd.read_csv(f'{input_filepath}gardner.csv', parse_dates=[2])
gardner.describe()
# Out:
#               AWND         PRCP         SNWD         TAVG         TMAX  \
# count  2464.000000  6299.000000  5063.000000  6301.000000  6301.000000
# mean      0.573957     0.289078    13.912107    44.026504    50.710522
# std       0.619283     0.519665    21.528531    11.294813    14.229234
# min       0.000000     0.000000     0.000000     5.000000     8.000000
# 25%       0.000000     0.000000     0.000000    35.000000    39.000000
# 50%       0.450000     0.000000     0.000000    42.000000    48.000000
# 75%       0.890000     0.400000    26.000000    52.000000    61.000000
# max       3.580000     6.500000   110.000000    77.000000    94.000000
#
#               TMIN         TOBS         WESD
# count  6299.000000  6300.000000  6305.000000
# mean     39.065248    41.653492     4.759873
# std       9.639733    10.048830     7.847762
# min       3.000000     4.000000     0.000000
# 25%      32.000000    34.000000     0.000000
# 50%      38.000000    41.000000     0.000000
# ...

# %%
print(boeing.shape, gardner.shape)
# Out:
# (6309, 21) (6305, 11)

# %% [markdown]
# We want tidy data, so let's join on the date.

# %%
weather = pd.merge(boeing, gardner, how='inner', on='DATE')
print(weather.shape)
weather.head()
# Out:
# (6297, 31)
#      STATION_x                       NAME_x       DATE  AWND_x    FMTM  \
# 0  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-01    5.14  1129.0
# 1  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-02    4.70   354.0
# 2  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-03    6.93  2031.0
# 3  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-04    1.12    58.0
# 4  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-05    3.80  1913.0
#
#      PGTM  PRCP_x  TAVG_x  TMAX_x  TMIN_x  ...    STATION_y  \
# 0  1125.0    0.63    45.0    54.0    36.0  ...  USS0021B21S
# 1   555.0    0.06    49.0    55.0    43.0  ...  USS0021B21S
# 2  1416.0    0.01    47.0    55.0    39.0  ...  USS0021B21S
# 3  1113.0    0.00    49.0    54.0    44.0  ...  USS0021B21S
# 4   519.0    0.26    49.0    54.0    43.0  ...  USS0021B21S
#
#                  NAME_y  AWND_y  PRCP_y  SNWD  TAVG_y  TMAX_y  TMIN_y  TOBS  \
# 0  MOUNT GARDNER, WA US     NaN     0.0   NaN    32.0    34.0    30.0  33.0
# ...

# %% [markdown]
# The NANs for the weather codes essentially mean that that weather type didn't happen, so I'll replace them with a 0

# %%
weather = weather.fillna(0)
weather.head()
# Out:
#      STATION_x                       NAME_x       DATE  AWND_x    FMTM  \
# 0  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-01    5.14  1129.0
# 1  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-02    4.70   354.0
# 2  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-03    6.93  2031.0
# 3  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-04    1.12    58.0
# 4  USW00024234  SEATTLE BOEING FIELD, WA US 2002-01-05    3.80  1913.0
#
#      PGTM  PRCP_x  TAVG_x  TMAX_x  TMIN_x  ...    STATION_y  \
# 0  1125.0    0.63    45.0    54.0    36.0  ...  USS0021B21S
# 1   555.0    0.06    49.0    55.0    43.0  ...  USS0021B21S
# 2  1416.0    0.01    47.0    55.0    39.0  ...  USS0021B21S
# 3  1113.0    0.00    49.0    54.0    44.0  ...  USS0021B21S
# 4   519.0    0.26    49.0    54.0    43.0  ...  USS0021B21S
#
#                  NAME_y  AWND_y  PRCP_y  SNWD  TAVG_y  TMAX_y  TMIN_y  TOBS  \
# 0  MOUNT GARDNER, WA US     0.0     0.0   0.0    32.0    34.0    30.0  33.0
# ...

# %% [markdown]
# And finally merge the weather with the mission data to get our final dataset to use.

# %%
data = pd.merge(sar_clean, weather, how='inner', left_on='date', right_on='DATE')

# %%
print(data.shape)

pd.set_option('display.max_columns', None) #show all the columns
data.head()
# Out:
# (6281, 46)
#         date  mission  Year  Month  Week  Day  Dayofweek  Dayofyear  \
# 0 2002-01-01        1  2002      1     1    1          1          1
# 1 2002-01-02        0  2002      1     1    2          2          2
# 2 2002-01-03        1  2002      1     1    3          3          3
# 3 2002-01-04        0  2002      1     1    4          4          4
# 4 2002-01-05        1  2002      1     1    5          5          5
#
#    Is_month_end  Is_month_start  Is_quarter_end  Is_quarter_start  \
# 0         False            True           False              True
# 1         False           False           False             False
# 2         False           False           False             False
# 3         False           False           False             False
# 4         False           False           False             False
#
#    Is_year_end  Is_year_start     Elapsed    STATION_x  \
# 0        False           True  1009843200  USW00024234
# ...

# %% [markdown]
# Lastly, I'll remove the unnessecary column names including station names and weather measurements that wouldn't be included in a standard forecast- more specifically, the wind gust information.

# %%
data.drop(['date', 'STATION_x', 'NAME_x', 'STATION_y','NAME_y', 'WDF2', 'WDF5', 'WSF2', 'WSF5', 'PGTM', 'FMTM'], axis=1, inplace=True)

# %%
# Save the data table for now.
interim_filepath = '../data/interim/'
data.to_csv(f'{interim_filepath}sar_weather_df.csv', index=False)

# %%
data.columns
# Out:
# Index(['mission', 'Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
#        'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start',
#        'Is_year_end', 'Is_year_start', 'Elapsed', 'DATE', 'AWND_x', 'PRCP_x',
#        'TAVG_x', 'TMAX_x', 'TMIN_x', 'TSUN', 'WT01', 'WT02', 'WT03', 'WT05',
#        'WT08', 'WT10', 'AWND_y', 'PRCP_y', 'SNWD', 'TAVG_y', 'TMAX_y',
#        'TMIN_y', 'TOBS', 'WESD'],
#       dtype='object')
